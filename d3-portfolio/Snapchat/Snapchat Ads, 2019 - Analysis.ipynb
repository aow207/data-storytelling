# %% [markdown]
# # Snapchat Ads, 2019
#
# Snapchat released a database of all of the Political and Advocacy Ads ran through its platform.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42 #makes text editable in illustrator

# %matplotlib inline

# %%
df = pd.read_csv("PoliticalAds.csv", encoding='latin-1')

# %%
df
# Out:
#                                                    ADID  \
# 0     af4ee169de66672b1103707506b24b158e6e96d2aa5776...
# 1     b0f05f235fb6ff4f6e6b86f8c21546083b5de3d6183254...
# 2     1336643ba5a013abb955661a27b5fe865936b59717e2b4...
# 3     36d5093025938ead895780113f24aaf7b147e4e273b6da...
# 4     bc7fe5e9969373d1d1807dcea9362375e9b1e8088722ce...
# 5     dbb6a51c35bcfbcebc90e4e2b5520ba602dd798d33d45c...
# 6     b3feeb961ce982d739de6a047334f1a15db3e87016c6ca...
# 7     ea0c27d0fd4bdd60f796ccece747bbc46c090015e095ad...
# 8     1d5bb066336827eacb5bf31ae875450c49a22067225ebc...
# 9     4768c9e2cacd50e49d8e8e8e0f8f9817c8f1c6ef7ce18a...
# 10    a5ea4af82361bd9afccb54d3b6879654d825dcee3cf637...
# 11    9c40bd07f34f29458578701e52cc3747d26b930b563e74...
# 12    0f9bb919432d8df9775a2e7434f45517fd54758c139485...
# 13    2550384561a711f1ca598951232f245be440798fff4c6a...
# 14    05f58d5076fc4c57081a497ef46f820f39eae5c12de833...
# 15    a02136f0c04d97a519f8b84fe84e4ae5275e77258765c9...
# ...

# %%
df.shape
# Out:
# (2285, 27)

# %% [markdown]
# ## Which countries have the most Snapchat political ads?

# %%
df.CountryCode.value_counts()
# Out:
# united states           1186
# norway                   339
# canada                   263
# united kingdom            76
# denmark                   71
# france                    55
# netherlands               54
# kuwait                    35
# austria                   31
# belgium                   27
# australia                 19
# india                     18
# finland                   18
# ireland                   14
# poland                    14
# sweden                    13
# germany                   10
# switzerland               10
# south africa              10
# argentina                  6
# united arab emirates       5
# turkey                     4
# lithuania                  3
# brazil                     1
# puerto rico                1
# chile                      1
# new zealand                1
# Name: CountryCode, dtype: int64

# %% [markdown]
# ## Most expensive Snapchat ads

# %%
df.sort_values(by='Spend', ascending=False)
# Out:
#                                                    ADID  \
# 1602  b16efc44dee3bba2d17941c5a4cb3aef471ca2d1bb92a2...
# 522   a80a357250899cc46a3ba443460af3513809d467501658...
# 1207  4023543497dea3eafdfce564b0c5bc2d9d510484a51e4c...
# 1215  71ea5886d0aca272a7deda5495678db8452f66b0bad102...
# 1373  19decfa75bafcd99d74f9c86c11ef9b0a95ca1867eca76...
# 336   97a6f332ac3db4cc5c2e73ee4a008737d49084a32bc016...
# 2219  d91a532400b522105ae1e395491420d1439bee9b6e77be...
# 180   88c40a58ecb7fe0c1fbfb60749328a60cdbcfe581bef55...
# 1839  2b4ce1f70c8b1dea3e9df5b818c52b5acb2e4f47d08c22...
# 2069  23325fa5fdecc98e28f16bba829dbf4036822c96690796...
# 1786  ee40a205809d7620b4cd185e6ba0c035e0e91dd34785bd...
# 729   94bcf16c314bf7859ccb2f30facf6b6b7b4c3b0386efdc...
# 1179  41482c57299fd18c27f019c90d1ba1ea358f372e8f0139...
# 1479  1eb174c6f4ae5ebb491e33aa1488486ddf5fa49aefdb75...
# 1684  70c7c723b6d1f1d7c27204fdd06e4d5766e06834f550d4...
# 983   9dd6a5ab648d439629a1ca9e973921f5ad9b5a52dacaae...
# ...

# %%
# How much was spent in total?
df.Spend.sum()
# Out:
# 3493335

# %% [markdown]
# ## Most popular?

# %%
df.sort_values(by='Impressions', ascending=False)
# Out:
#                                                    ADID  \
# 2219  d91a532400b522105ae1e395491420d1439bee9b6e77be...
# 522   a80a357250899cc46a3ba443460af3513809d467501658...
# 1215  71ea5886d0aca272a7deda5495678db8452f66b0bad102...
# 1602  b16efc44dee3bba2d17941c5a4cb3aef471ca2d1bb92a2...
# 2069  23325fa5fdecc98e28f16bba829dbf4036822c96690796...
# 971   313e13c02c616af3e65bf539a040fe11046a56472870ab...
# 1967  9326eb69178e38bca6ffa7a50c67fe5252d9a2ebc71b6d...
# 729   94bcf16c314bf7859ccb2f30facf6b6b7b4c3b0386efdc...
# 98    28522d918c6b46a768942db2687ae495e11e393a997bc1...
# 972   7033c3858de78f6e1f7dc5f47d1e5288df1a631e342200...
# 54    74385479e38a28072d69477c0818472e10e38a38626054...
# 1179  41482c57299fd18c27f019c90d1ba1ea358f372e8f0139...
# 1207  4023543497dea3eafdfce564b0c5bc2d9d510484a51e4c...
# 1786  ee40a205809d7620b4cd185e6ba0c035e0e91dd34785bd...
# 1795  c00fb0d6b5daf969750bed8f31c52d3cafe422d3852083...
# 713   b7279825225266a025d0056de857c3f8c7be60a6600000...
# ...

# %% [markdown]
# ## Which languages?

# %%
df.Language.value_counts()
# Out:
# en       410
# fr        69
# nb        62
# nl        33
# da        28
# de        18
# en,es     13
# ar        11
# es         8
# nb,en      6
# nl,en      5
# fi         4
# ar,en      3
# de,en      2
# sv         1
# Name: Language, dtype: int64

# %% [markdown]
# ## Who are ads targeted at on the platform?

# %%
gender = df.Gender.value_counts()
gender
# Out:
# FEMALE    154
# MALE       59
# Name: Gender, dtype: int64
